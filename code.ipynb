# %% [markdown]
# # Chargement et Préparation des Données

# %%
import pandas as pd

# %%
df = pd.read_csv("books_data_t.csv/books_data_t.csv")
retrait= df[["Image","Lien Google", "Date publication", "infoLink"]]

df = df[["Titre", "Description", "Auteurs", "Editeur", "Genre", "Nb scores"]]
df = df.dropna(subset=["Titre", "Auteurs", "Editeur", "Genre", "Nb scores"])
df = df.head(1000)

df.head(1000)
# Out:
#                                                   Titre  \
# 5     The Church of Christ: A Biblical Ecclesiology ...
# 31    Voices from the Farm: Adventures in Community ...
# 33                              The Battleship Bismarck
# 42                              Tess and the Highlander
# 43     Beginner's Yoruba (Hippocrene Beginner's Series)
# ...                                                 ...
# 5106  NEW WORLD 96 SPANISH/ENGLISH DICTIONARY SOFTBOUND
# 5109  Beyond Glory: Medal of Honor Heroes in Their O...
# 5112                                              Ashes
# 5115                        How to Bring Them to Christ
# 5130  Talk About Stress : Managing Stress in the Int...
#
#                                             Description  \
# 5     In The Church of Christ: A Biblical Ecclesiolo...
# 31    Twenty-five years ago, at the height of the co...
# 33    The Bismarck is perhaps the most famous – and ...
# 42    In 1543, on a windswept isle off of Scotland, ...
# 43    "Beginner's Yoruba" is now available with two ...
# ...                                                 ...
# 5106  The completely revised, second edition of the ...
# 5109  A stirring oral history of the nation's Medal ...
# 5112  “Somebody comes into the Zen center with a lig...
# 5115  Most Christians intensely desire to bring othe...
# 5130  Stress is the greatest killer of modern times....
#
#                                                 Auteurs  \
# 5                                  ['Everett Ferguson']
# 31                                      ['Rupert Fike']
# 33                                 ['Stefan Draminski']
# 42                                   ['May Mcgoldrick']
# 43                              ['Kayode J. Fakinlede']
# ...                                                 ...
# 5106                            ['Salvatore Ramondino']
# 5109                                    ['Larry Smith']
# 5112  ['Seung Sahn', 'Sungsan Tae Sŏnsa', 'Stephen M...
# 5115                                   ['R. A. Torrey']
# 5130               ['Alok Chakrawal', 'Pratibha Goyal']
#
#                          Editeur                          Genre  Nb scores
# 5     Wm. B. Eerdmans Publishing                   ['Religion']        5.0
# 31       Book Publishing Company  ['Biography & Autobiography']        1.0
# 33         Bloomsbury Publishing                    ['History']        1.0
# 42                Harper Collins           ['Juvenile Fiction']        2.0
# 43              Hippocrene Books     ['Foreign Language Study']        1.0
# ...                          ...                            ...        ...
# 5106                     Berkley     ['Foreign Language Study']        2.0
# 5109      W. W. Norton & Company  ['Biography & Autobiography']        1.0
# 5112                 Grove Press                   ['Religion']        4.0
# 5115              Whitaker House                   ['Religion']        2.0
# 5130               Studera Press       ['Business & Economics']        1.0
#
# [1000 rows x 6 columns]

# %%
def nettoyer_genre(genre):

    if isinstance(genre, list):  
        return genre
    
    genre = genre.replace("&", ",")
    #genre = genre.replace(" ", "")
    genre = genre.replace("[", "").replace("]", "").replace("'", "")
    return genre.split(",")

df["Genre"] = df["Genre"].apply(nettoyer_genre)
df[["Titre", "Genre"]].head(10)
# Out:
#                                                 Titre  \
# 5   The Church of Christ: A Biblical Ecclesiology ...
# 31  Voices from the Farm: Adventures in Community ...
# 33                            The Battleship Bismarck
# 42                            Tess and the Highlander
# 43   Beginner's Yoruba (Hippocrene Beginner's Series)
# 45  King James: Believe the Hype---The LeBron Jame...
# 47  Building the timber frame house: The revival o...
# 54      Open marriage;: A new life style for couples,
# 58  No place to cry: The hurt and healing of sexua...
# 59                                   Trouble on Titan
#
#                            Genre
# 5                     [Religion]
# 31  [Biography ,  Autobiography]
# 33                     [History]
# 42            [Juvenile Fiction]
# 43      [Foreign Language Study]
# 45        [Sports ,  Recreation]
# 47                [Architecture]
# 54     [Family ,  Relationships]
# 58                    [Religion]
# 59                     [Fiction]

# %% [markdown]
# # Répartition des genres

# %%
from collections import Counter

# %%
compteur_genres = Counter()
for genres in df["Genre"]:
    compteur_genres.update(genres)

df_genres = pd.DataFrame(compteur_genres.items(), columns=["Genre", "Nb Occurrences"])
df_genres["%"] = (df_genres["Nb Occurrences"] / df_genres["Nb Occurrences"].sum()) * 100
df_genres = df_genres.sort_values(by="Nb Occurrences", ascending=False)

df_genres.head(20)
# Out:
#                Genre  Nb Occurrences          %
# 11           Fiction             242  19.690806
# 4   Juvenile Fiction              77   6.265256
# 0           Religion              72   5.858421
# 3            History              60   4.882018
# 2      Autobiography              49   3.986981
# 1         Biography               49   3.986981
# 23         Economics              26   2.115541
# 22         Business               26   2.115541
# 20             Mind               25   2.034174
# 19              Body              25   2.034174
# 21            Spirit              25   2.034174
# 6            Sports               21   1.708706
# 7         Recreation              21   1.708706
# 32           Science              20   1.627339
# 46         Computers              18   1.464605
# 9            Family               17   1.383238
# 36           Cooking              17   1.383238
# 10     Relationships              17   1.383238
# 15           Fitness              17   1.383238
# 14           Health               17   1.383238
